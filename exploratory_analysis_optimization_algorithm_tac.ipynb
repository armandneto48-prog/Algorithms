# %%
import random

# 1. Dataset de Sensores (1000 pontos) - Ruído de Micro-vibração (em milímetros)
# Valores próximos de zero, onde a soma de 3 pode indicar ressonância destrutiva
sensores = [round(random.uniform(-50.0, 50.0), 2) for _ in range(1000)]

# 2. Datasets de Produtividade Marginal vs Custo (Salários)
# O valor representa o "Saldo de Valor" (Produtividade - Custo do Funcionário)
# Se o saldo é 0, o funcionário está em equilíbrio perfeito.
empresa_A = [random.randint(-100, 100) for _ in range(15)]
empresa_B = [random.randint(-200, 200) for _ in range(50)]
big_tech  = [random.randint(-500, 500) for _ in range(200)]

print(f"Dataset Sensores (Amostra): {sensores[:5]}")
print(f"Dataset Big Tech (Amostra): {big_tech[:5]}")
# Out:
# Dataset Sensores (Amostra): [21.85, -12.94, 39.01, -10.07, 44.03]
# Dataset Big Tech (Amostra): [376, -387, -441, -316, 347]
