# %%
# Generating Random values:

import numpy as np
num = np.random.uniform()
print(num)
# Out:
# 0.4680096389829559

# %%
import numpy as np
arr = np.random.uniform(size=5)
print(arr)

# All the values in the output, even being different, has the same probability of occurying.
# Out:
# [0.6284686  0.50152662 0.62489119 0.36294463 0.06808291]

# %%
import numpy as np
rng = np.random.default_rng()  # Create a Generator instance
m = rng.uniform(1, 5, size=(2, 3))
print(m)
# Out:
# [[2.89984033 2.87130878 1.77582487]
#  [2.48216755 2.26615554 4.15713055]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

low = 10
high = 20
size = 1000

data = np.random.uniform(low, high, size)

sns.histplot(data, bins=30, kde=False, color='skyblue', edgecolor='black')

plt.title(f"Uniform Distribution (Range: {low} to {high})")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
