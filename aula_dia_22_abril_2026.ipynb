# %%
[] 

def pega(N, []):
    recebe_valor = 1
    for i in range(0, N-1):
        a = novo
        novo = None
        recebe_valor = a

    return recebe_valor

print(pega (5, 10))
# Out:
# None

# %%
def inicio(point, next):
    if point == next:
        return point
    else:
        return inicio(next, point)

# %%
def pega(inicio, fim):
    while(inicio != None):
        pega = inicio
        inicio = fim
        fim = pega
    return pega

# pega(5,10)

# %%
def class(cabeça,corpo):
