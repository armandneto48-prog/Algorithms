# %%
# Condicionamento de chaves / packaging of access keys:

"""def condVersaoJava(k):
    r = 0
    i = 0
    while(i < len(k)):
	r += ord(k[i])*pow(31,len(k)-i-1)
	i += 1
    return r


def condition(k):
    r = 0
    i = 0
    while(i < len(k)):
	r += ord(k[i])
	i += 1
    return r
"""

# Código corriido pelo gemini:


def condVersaoJava(k):
    r = 0
    i = 0
    n = len(k)
    while i < n:
        # A identação é obrigatória dentro do while
        # Usamos o operador ** para potência ou a função pow()
        r += ord(k[i]) * (31 ** (n - i - 1))
        i += 1
    return r

def condition(k):
    r = 0
    i = 0
    while i < len(k):
        # Correção da identação
        r += ord(k[i])
        i += 1
    return r

# %%
# Dicionário em Python: Open Adressing com linear Probing:

#main

#Professor:

"""d = {}
d[‘ana’] = 1
d[‘jose’]=1
d[‘rui’]=1
d[‘ana’] += 1
if(‘jose’ in d):
      print(yes)
print(d.keys())
print(d.values())
for x in d:
      printf(d[x])"""

# Gemini:

d = {}
d['ana'] = 1
d['jose'] = 1
d['rui'] = 1
d['ana'] += 1

if 'jose' in d:
    print("yes")  # Aspas necessárias para tratar como string

print(d.keys())
print(d.values())

for x in d:
    print(d[x])  # Em Python usa-se print(), não printf()

# %%
# Cuckoo Hashing:

d = {}
d['ana'] = 1
d['jose'] = 1
d['rui'] = 1
d['ana'] += 1

if 'jose' in d:
    print("yes")  # Aspas necessárias para tratar como string

print(d.keys())
print(d.values())

for x in d:
    print(d[x])  # Em Python usa-se print(), não printf()

# função lookup(x)
     #return    𝑇𝑎𝑏1[ℎ(𝑥)]==𝑥   ∨   𝑇𝑎𝑏2[ℎ^′ (𝑥)]==𝑥
# Out:
# yes
# dict_keys(['ana', 'jose', 'rui'])
# dict_values([2, 1, 1])
# 2
# 1
# 1
