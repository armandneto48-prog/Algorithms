# %%
# exercício de de construção de árvores:

def arvore(folha1,folha2):
    folha1.pt = pt.folha3
    folha3.pt = pt.folha4

def arvore2(folha3,folha7):
    folha3.pt=pt.folha4
    folha7(folha6,folha10):
        folha10.pt = pt.folha8

# %%
#  pelo professor:

def profundidade(raiz): # criação da base inicial da árvore:

    if(raiz in None): # criação do ciclo if para o primeiro nó        return 0
        return 0
    L = profundidade(raiz.esq) # criação da raiz e uma "ponte à esquerda"
    R = profundidade(raiz.dir) # mesma coisa, porém aplicada à direita

return 1 + (L if L > R else R) #

# %%
# exercício 6 baseado no que o professor criou (minha tentativa):

def arvore(raiz1,raiz2):
        L = raiz1
        R = raiz2
    criacao(raiz1):
        criacao(raiz2):
        K = raiz(raiz2)
    return K

# %%
# exercício 7: desenha uma árvore binária que teha uma disposição física real i.e,
# nós, filhos e folhas visualmente representadas como na disposição real da árvore

# exercício 6 base para o exercício 7:

def profundidade(raiz): # criação da base inicial da árvore:

    if(raiz in None): # criação do ciclo if para o primeiro nó        return 0
        return 0
    L = profundidade(raiz.esq) # criação da raiz e uma "ponte à esquerda"
    R = profundidade(raiz.dir) # mesma coisa, porém aplicada à direita

    return 1 + (L if L > R else R)

# sugestão de resolução do professor:

def profundidade(R):
    if(raiz is None):
        return 0
    if(raiz.bil == 1):
        return 1 + profundidade2(raiz.esq)
    else:
        return 1 + profundidade(raiz.dir)

# %%
# exercício sobre classes no AVL:

# exercício 6 base para o exercício 7:

def profundidade(raiz): # criação da base inicial da árvore:

    if(raiz in None): # criação do ciclo if para o primeiro nó        return 0
        return 0
    L = profundidade(raiz.esq) # criação da raiz e uma "ponte à esquerda"
    R = profundidade(raiz.dir) # mesma coisa, porém aplicada à direita

    return 1 + (L if L > R else R)

def conjunto(folha1,folha2):
